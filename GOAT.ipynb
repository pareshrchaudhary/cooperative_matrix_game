# %% [markdown]
# <a href="https://colab.research.google.com/github/pareshrchaudhary/toy_cooperation/blob/main/GOAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Improving Human-AI Coordination through Online Adversarial Training and Generative Models

# %%
# @title Setup {"display-mode":"form"}
# !git clone https://github.com/pareshrchaudhary/toy_cooperation.git
# %cd /content/toy_cooperation
# %pip install -r requirements.txt
# %pip install -e .
# Out:
# Cloning into 'toy_cooperation'...
# remote: Enumerating objects: 868, done.
# remote: Counting objects: 100% (868/868), done.
# remote: Compressing objects: 100% (472/472), done.
# remote: Total 868 (delta 399), reused 861 (delta 392), pack-reused 0 (from 0)
# Receiving objects: 100% (868/868), 28.09 MiB | 12.71 MiB/s, done.
# Resolving deltas: 100% (399/399), done.
# /content/toy_cooperation
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...

# %%
# @title Payoff matrix {"run":"auto","vertical-output":true}
# %run /content/toy_cooperation/env/cmg/matrix.py

# %%
# @title Self-Play {"run":"auto","vertical-output":true,"display-mode":"form"}
# %run /content/toy_cooperation/runner/sp.py
# Out:
# Training SP with 8 policies for 200 episodes and 4 seeds.
# Step 50/200, Avg BR Self-play: 0.8381, Avg BR Cross-play: 0.8381
# Step 100/200, Avg BR Self-play: 1.1826, Avg BR Cross-play: 1.1826
# Step 150/200, Avg BR Self-play: 1.1906, Avg BR Cross-play: 1.1906
# Step 200/200, Avg BR Self-play: 1.1938, Avg BR Cross-play: 1.1938
# Average BR-SP reward: 1.1938
# Average BR-XP reward: 1.1938
# /content/toy_cooperation/utils/visualize.py:202: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Results saved to /content/toy_cooperation/results/sp/cmg_s_suboptimal/8

# %%
# @title Trajedi {"vertical-output":true,"display-mode":"form"}
# %run /content/toy_cooperation/runner/trajedi.py
# Out:
# Training Trajedi with 8 policies for 200 episodes and 4 seeds.
# Step 50/200, Avg BR Self-play: 0.8284, Avg BR Cross-play: 0.8284
# Step 100/200, Avg BR Self-play: 1.1738, Avg BR Cross-play: 1.1738
# Step 150/200, Avg BR Self-play: 1.1841, Avg BR Cross-play: 1.1841
# Step 200/200, Avg BR Self-play: 1.1889, Avg BR Cross-play: 1.1889
# Average BR-SP reward: 1.1889
# Average BR-XP reward: 1.1889
# /content/toy_cooperation/utils/visualize.py:202: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Results saved to /content/toy_cooperation/results/trajedi/cmg_s_suboptimal/8

# %%
# @title MEP {"run":"auto","vertical-output":true}
# %run /content/toy_cooperation/runner/mep.py
# Out:
# Training MEP with 8 policies for 200 episodes and 4 seeds.
# Step 50/200, Avg BR Self-play: 0.8893, Avg BR Cross-play: 0.8893
# Step 100/200, Avg BR Self-play: 1.1719, Avg BR Cross-play: 1.1719
# Step 150/200, Avg BR Self-play: 1.1849, Avg BR Cross-play: 1.1849
# Step 200/200, Avg BR Self-play: 1.1900, Avg BR Cross-play: 1.1900
# Average BR-SP reward: 1.1900
# Average BR-XP reward: 1.1900
# /content/toy_cooperation/utils/visualize.py:202: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Results saved to /content/toy_cooperation/results/mep/cmg_s_suboptimal/8

# %%
# @title CoMeDi
# %run /content/toy_cooperation/runner/comedi.py
# Out:
# Training Comedi with 8 policies for 200 episodes and 4 seeds.
# Step 50/200, Avg BR Self-play: 0.6246, Avg BR Cross-play: 0.5931
# Step 100/200, Avg BR Self-play: 1.1735, Avg BR Cross-play: 1.1735
# Step 150/200, Avg BR Self-play: 1.1864, Avg BR Cross-play: 1.1864
# Step 200/200, Avg BR Self-play: 1.1910, Avg BR Cross-play: 1.1910
# Average BR-SP reward: 1.1910
# Average BR-XP reward: 1.1910
# /content/toy_cooperation/utils/visualize.py:202: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Results saved to /content/toy_cooperation/results/comedi/cmg_s_suboptimal/8

# %%
# @title VAE Training {"run":"auto","vertical-output":true,"display-mode":"form"}
beta = "0.1" # @param {"type":"string","placeholder":"0.1"}
# %run /content/toy_cooperation/trainer/vae_trainer.py --beta $beta
# Out:
# Using 1 seeds out of 4 available seeds
# Data augmentation: Added 24 mismatched pairs (total: 48)
# Loaded 24 policies for training (from start, mid, and end stages)
# Epoch 100/2000:
#   Total: 3.462420, Recon: 3.224948, KL: 2.374724
# Epoch 200/2000:
#   Total: 3.340189, Recon: 3.049628, KL: 2.905608
# Epoch 300/2000:
#   Total: 3.270304, Recon: 3.020967, KL: 2.493374
# Epoch 400/2000:
#   Total: 3.243842, Recon: 2.977318, KL: 2.665243
# Epoch 500/2000:
#   Total: 3.239214, Recon: 2.938891, KL: 3.003230
# Epoch 600/2000:
#   Total: 3.262600, Recon: 2.956992, KL: 3.056083
# Epoch 700/2000:
#   Total: 3.229193, Recon: 2.940303, KL: 2.888908
# Epoch 800/2000:
#   Total: 3.210213, Recon: 2.938330, KL: 2.718824
# Epoch 900/2000:
#   Total: 3.240743, Recon: 2.948097, KL: 2.926461
# Epoch 1000/2000:
#   Total: 3.189352, Recon: 2.920354, KL: 2.689981
# Epoch 1100/2000:
#   Total: 3.165291, Recon: 2.905420, KL: 2.598715
# Epoch 1200/2000:
#   Total: 3.189929, Recon: 2.909899, KL: 2.800291
# ...

# %%
# @title GOAT {"run":"auto","vertical-output":true,"display-mode":"form"}
kl_coeff = "0.0005" # @param {"type":"string","placeholder":"0.4"}
ent_coeff = "0.001" # @param {"type":"string","placeholder":"0.001"}

# %run /content/toy_cooperation/runner/goat.py --kl_coeff $kl_coeff --entropy_coeff $ent_coeff
# Out:
# Training GOAT with BR policy for 200 episodes, and 1 seeds.
# Step 1/200, Avg BR vs VAE: 0.1543, Avg VAE vs VAE: 0.3342
#   VAE vs BR: 0.0771
#   BR vs VAE: 0.0771
#   Regret: 0.2571
# Step 51/200, Avg BR vs VAE: 0.4064, Avg VAE vs VAE: 0.4558
#   VAE vs BR: 0.2033
#   BR vs VAE: 0.2031
#   Regret: 0.2527
#   Loss: 0.2743
# Step 101/200, Avg BR vs VAE: 0.7040, Avg VAE vs VAE: 0.5900
#   VAE vs BR: 0.3520
#   BR vs VAE: 0.3520
#   Regret: 0.2380
#   Loss: -0.8570
# Step 151/200, Avg BR vs VAE: 0.4515, Avg VAE vs VAE: 0.6055
#   VAE vs BR: 0.2257
#   BR vs VAE: 0.2257
#   Regret: 0.3798
#   Loss: 1.1256
# Step 200/200, Avg BR vs VAE: 0.0783, Avg VAE vs VAE: 0.4197
#   VAE vs BR: 0.0391
#   BR vs VAE: 0.0391
#   Regret: 0.3805
#   Loss: 2.1682
# Average BR vs VAE reward: 0.0783
# /content/toy_cooperation/utils/visualize.py:202: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ...
